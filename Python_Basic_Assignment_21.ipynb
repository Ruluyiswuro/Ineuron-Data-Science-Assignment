# %% [markdown]
# # Python Basic Assignment 21

# %% [markdown]
# #### Q1. Add the current date to the text file today.txt as a string

# %%
import datetime
file = open('today.txt', 'w')
file.write(datetime.datetime.now().strftime("%d-%m-%y"))
file.close()

# %% [markdown]
# #### Q2. Read the text file today.txt into string today_string.

# %%
file= open('today.txt', 'r')
today_string = file.read()
print(today_string)
# Out:
# 19-08-22

# %% [markdown]
# #### Q3. Parse the date from todat_string.

# %%
from datetime import datetime
parsed_date = datetime.strptime(today_string, "%d-%m-%y")
print(parsed_date)
# Out:
# 2022-08-19 00:00:00

# %% [markdown]
# #### Q4. List the files in your current directory.

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# .condarc
# .gitconfig
# Agent_Login_Report.xlsx
# Agent_Performance_Report.xlsx
# application_log.txt
# Atsu_Full_Pic.jpg
# Attribute DataSet.xlsx
# Attribute DataSetEdited.xlsx
# books.csv
# books.db
# Dress Sales.xlsx
# DressSales.csv
# Exception Handling 12 - 06.ipynb
# FitBit Data.json
# FitbitTaskandSuperstore_USA.ipynb
# FitBit_data.csv
# For_loop_28-05-22.ipynb
# functions 5th June.ipynb
# globe.png
# graph,sns,seaborn,plotly,matplotlib.ipynb
# haberman.csv
# haberman.names
# HSBCC.docx
# iterator and iterable, generator, basic file operation.ipynb
# logfile.txt
# logging.ipynb
# My boarding pass.pdf
# mysqltaskpractice.ipynb
# mysqltaskworkpractice
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{081875da-1554-11ed-9ed7-00224845c454}.TM.blf
# NTUSER.DAT{081875da-1554-11ed-9ed7-00224845c454}.TMContainer00000000000000000001.regtrans-ms
# NTUSER.DAT{081875da-1554-11ed-9ed7-00224845c454}.TMContainer00000000000000000002.regtrans-ms
# ntuser.ini
# Numpy.ipynb
# ...

# %% [markdown]
# #### Q5. Create a list of the files in your parent directory (minimum five files should be available).

# %%
import os
os.listdir()
# Out:
# ['.astropy',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.cufflinks',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.Ld2VirtualBox',
#  '.matplotlib',
#  '.ms-ad',
#  '3D Objects',
#  'Agent_Login_Report.xlsx',
#  'Agent_Performance_Report.xlsx',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'application_log.txt',
#  'Atsu_Full_Pic.jpg',
#  'Attribute DataSet.xlsx',
#  'Attribute DataSetEdited.xlsx',
#  'books.csv',
#  'books.db',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Dress Sales.xlsx',
#  'DressSales.csv',
#  'Exception Handling 12 - 06.ipynb',
#  'Favorites',
#  'FitBit Data.json',
#  'FitbitTaskandSuperstore_USA.ipynb',
#  'FitBit_data.csv',
#  'For_loop_28-05-22.ipynb',
#  'functions 5th June.ipynb',
#  'globe.png',
#  'graph,sns,seaborn,plotly,matplotlib.ipynb',
#  'haberman.csv',
#  'haberman.names',
#  'HSBCC.docx',
#  'IntelGraphicsProfiles',
# ...

# %% [markdown]
# #### Q6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time , and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def process_one():
    print(f'Process_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Process_one_Endtime -> {datetime.datetime.now()}')
    
def process_two():
    print(f'Process_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Process_two_Endtime -> {datetime.datetime.now()}')

def process_three():
    print(f'Process_three_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Process_three_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=process_one)
    p2 = multiprocessing.Process(target=process_two)
    p3 = multiprocessing.Process(target=process_three)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()
    
process_one()
process_two()
process_three()
# Out:
# Process_one_Starttime -> 2022-08-19 18:31:10.220848
# Process_one_Endtime -> 2022-08-19 18:31:14.225812
# Process_two_Starttime -> 2022-08-19 18:31:14.227866
# Process_two_Endtime -> 2022-08-19 18:31:15.243359
# Process_three_Starttime -> 2022-08-19 18:31:15.245432
# Process_three_Endtime -> 2022-08-19 18:31:20.252270

# %% [markdown]
# #### Q7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('29/01/2000','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 2000-01-29 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# #### Q8. What day of the week was your day of birth.

# %%
from datetime import datetime
my_DOB = datetime(2000, 1, 29)
my_DOB.strftime("%A")
# Out:
# 'Saturday'

# %% [markdown]
# #### Q9. When will be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("29/01/2000",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1972, 9, 12, 0, 0)
